# %%
import sys
sys.path.insert(0,'/home/tiagoalves/rrodrigues/desafiosonhador')
from data_preprocessing import MMChallengeData
import os.path as path
import pandas as pd
from pandas.core.frame import DataFrame

df = DataFrame.from_csv('/home/tiagoalves/rrodrigues/MuTectsnvs.csv')

# %%
df2 = DataFrame.from_csv('/home/tiagoalves/rrodrigues/globalClinTraining.csv')
df2.set_index(df2.columns[17], drop=False, append=False, inplace=True)

# %%
df2
# Out:
#                                                       Patient  D_Age D_Gender  \
# WES_mutationFileMutect
# NaN                                                 MM-09-270   41.0     Male
# NaN                                                 MM-09-272   78.0     Male
# NaN                                                 MM-09-285   65.0     Male
# NaN                                                 MM-09-292   78.0     Male
# NaN                                                 MM-09-294   63.0     Male
# NaN                                                 MM-09-305   79.0   Female
# NaN                                                 MM-10-002   53.0   Female
# NaN                                                 MM-10-009   72.0   Female
# NaN                                                 MM-10-010   52.0     Male
# NaN                                                 MM-10-021   76.0   Female
# NaN                                                 MM-10-026   74.0     Male
# ...

# %%
df3 = df2.join(df)

# %%
df3["snoZ5"].value_counts()
# Out:
# 3.0    6
# Name: snoZ5, dtype: int64

# %%
df4 = DataFrame.from_csv('/home/tiagoalves/rrodrigues/MuTectsnvs_joined.csv')
# Out:
# /home/tiagoalves/miniconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2802: DtypeWarning: Columns (2,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
df4["snoZ5"].value_counts()
# Out:
# Series([], Name: snoZ5, dtype: int64)
